# %% [markdown]
# ### 동물상 판정기 ChatGPT 소스 원본 기반 최소한의 수정

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# 1. 데이터 로드 및 라벨링
data_dir = r'C:\Data\Sample\Animals2'  # 각 폴더가 들어있는 상위 폴더 경로
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150
batch_size = 32
epochs = 50

# 2. 데이터 생성기
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# 3. CNN 모델 구성
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# 4. 모델 학습
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs
)

# 5. 모델 저장
model.save(model_save_path)

# 6. 새로운 이미지로 예측
def predict_image(image_path, model_path):
    model = load_model(model_path)
    img = load_img(image_path, target_size=(img_width, img_height))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    
    predictions = model.predict(img_array)
    class_indices = train_generator.class_indices
    class_labels = list(class_indices.keys())
    
    for label, probability in zip(class_labels, predictions[0]):
        print(f"{label}: {probability:.4f}")
    
    return predictions[0]

# 예측 테스트
test_image_path = r'C:\Data\Sample\Beauty.jpg'
predict_image(test_image_path, model_save_path)
# Out:
# Found 38 images belonging to 4 classes.
# Found 13 images belonging to 4 classes.
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.0000e+00 - loss: 1.3946 - val_accuracy: 0.3077 - val_loss: 5.8654
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.2188 - loss: 6.0725 - val_accuracy: 0.2308 - val_loss: 4.0867
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 4.0867
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3333 - loss: 2.2241 - val_accuracy: 0.3846 - val_loss: 2.2528
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.3438 - loss: 2.4068 - val_accuracy: 0.3846 - val_loss: 1.6081
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.6081
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4062 - loss: 1.4418 - val_accuracy: 0.3846 - val_loss: 1.3906
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.1667 - loss: 1.5498 - val_accuracy: 0.3077 - val_loss: 1.3752
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.3752
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 1.2241 - val_accuracy: 0.2308 - val_loss: 1.3608
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.5625 - loss: 1.2408 - val_accuracy: 0.2308 - val_loss: 1.3307
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.3307
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5938 - loss: 1.1220 - val_accuracy: 0.3846 - val_loss: 1.3563
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.1667 - loss: 1.2676 - val_accuracy: 0.2308 - val_loss: 1.4289
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.4289
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 0.8700 - val_accuracy: 0.3077 - val_loss: 1.5361
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.5000 - loss: 1.1432 - val_accuracy: 0.3077 - val_loss: 1.4220
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.4220
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 0.8895 - val_accuracy: 0.2308 - val_loss: 1.4616
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.8438 - loss: 0.8396 - val_accuracy: 0.2308 - val_loss: 1.5324
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.5324
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 0.5585 - val_accuracy: 0.3077 - val_loss: 1.8665
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.6875 - loss: 0.8498 - val_accuracy: 0.3077 - val_loss: 1.8463
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.8463
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.3231 - val_accuracy: 0.2308 - val_loss: 2.1650
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.6875 - loss: 0.7020 - val_accuracy: 0.1538 - val_loss: 2.1049
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.1049
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.4170 - val_accuracy: 0.1538 - val_loss: 2.2068
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 1.0000 - loss: 0.2790 - val_accuracy: 0.2308 - val_loss: 2.6038
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 2.6038
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 0.8205 - val_accuracy: 0.2308 - val_loss: 2.3646
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9375 - loss: 0.3475 - val_accuracy: 0.1538 - val_loss: 2.2830
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.2830
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.2668 - val_accuracy: 0.1538 - val_loss: 2.3068
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 1.0000 - loss: 0.1212 - val_accuracy: 0.2308 - val_loss: 2.5909
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 2.5909
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.2442 - val_accuracy: 0.3077 - val_loss: 2.8297
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8333 - loss: 0.2476 - val_accuracy: 0.3077 - val_loss: 2.9544
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 2.9544
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1943 - val_accuracy: 0.3077 - val_loss: 2.7085
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 1.0000 - loss: 0.1507 - val_accuracy: 0.2308 - val_loss: 2.5852
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 2.5852
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0456 - val_accuracy: 0.3077 - val_loss: 2.7697
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 1.0000 - loss: 0.0620 - val_accuracy: 0.3077 - val_loss: 3.2419
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 3.2419
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 0.2308 - val_loss: 3.5324
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.9375 - loss: 0.0881 - val_accuracy: 0.2308 - val_loss: 3.8881
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 3.8881
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9688 - loss: 0.0724 - val_accuracy: 0.2308 - val_loss: 4.3116
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.2308 - val_loss: 5.1527
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Cat: 0.8219
# Dog: 0.0006
# Rabbit: 0.1376
# Turtle: 0.0399
# array([8.2190198e-01, 5.8953569e-04, 1.3760686e-01, 3.9901633e-02],
#       dtype=float32)

# %% [markdown]
# ### 코드 분리 (학습)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

from tkinter import filedialog

data_dir = filedialog.askdirectory(title = 'Training Dataset')

# 1. 데이터 로드 및 라벨링
data_dir = r'C:\Data\Sample\Animals2'  # 각 폴더가 들어있는 상위 폴더 경로
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150
batch_size = 32
epochs = 50

# 2. 데이터 생성기
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# 3. CNN 모델 구성
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# 4. 모델 학습
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs
)

# 5. 모델 저장
model.save(model_save_path)
# Out:
# Found 38 images belonging to 4 classes.
# Found 13 images belonging to 4 classes.
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.1562 - loss: 1.3923 - val_accuracy: 0.3846 - val_loss: 1.7860
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.1667 - loss: 3.5868 - val_accuracy: 0.2308 - val_loss: 2.5310
# Epoch 3/50
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 2.5310
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3125 - loss: 1.8597 - val_accuracy: 0.2308 - val_loss: 1.6458
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.0000e+00 - loss: 2.4883 - val_accuracy: 0.2308 - val_loss: 1.3616
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.3616
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6875 - loss: 1.2091 - val_accuracy: 0.3846 - val_loss: 1.3480
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.1667 - loss: 1.3304 - val_accuracy: 0.3846 - val_loss: 1.3184
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.3184
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 0.9745 - val_accuracy: 0.3846 - val_loss: 1.4767
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.2812 - loss: 1.5201 - val_accuracy: 0.3846 - val_loss: 1.3309
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.3309
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4688 - loss: 1.0345 - val_accuracy: 0.2308 - val_loss: 1.3891
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6667 - loss: 1.0719 - val_accuracy: 0.2308 - val_loss: 1.6681
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.6681
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3125 - loss: 1.2861 - val_accuracy: 0.2308 - val_loss: 1.5326
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8333 - loss: 0.6743 - val_accuracy: 0.2308 - val_loss: 1.4929
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.4929
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 0.8944 - val_accuracy: 0.1538 - val_loss: 1.3985
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.9062 - loss: 0.7650 - val_accuracy: 0.3077 - val_loss: 1.4966
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.4966
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5625 - loss: 0.7483 - val_accuracy: 0.3077 - val_loss: 1.5569
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.6667 - loss: 0.4993 - val_accuracy: 0.1538 - val_loss: 1.6279
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.6279
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.4786 - val_accuracy: 0.3846 - val_loss: 1.8092
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.8333 - loss: 0.3799 - val_accuracy: 0.2308 - val_loss: 1.9009
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.9009
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 0.4696 - val_accuracy: 0.2308 - val_loss: 1.8509
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 1.0000 - loss: 0.1120 - val_accuracy: 0.1538 - val_loss: 2.2011
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.2011
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.2711 - val_accuracy: 0.1538 - val_loss: 2.3259
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 1.0000 - loss: 0.1046 - val_accuracy: 0.1538 - val_loss: 2.4081
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.4081
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1027 - val_accuracy: 0.2308 - val_loss: 2.5984
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 1.0000 - loss: 0.0714 - val_accuracy: 0.2308 - val_loss: 2.8620
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 2.8620
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0395 - val_accuracy: 0.3077 - val_loss: 3.2520
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.2308 - val_loss: 3.8086
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 3.8086
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.1538 - val_loss: 4.4651
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.2308 - val_loss: 4.6366
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 4.6366
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.2308 - val_loss: 4.8745
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.2308 - val_loss: 5.1365
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 5.1365
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.2308 - val_loss: 5.4388
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.2308 - val_loss: 5.7927
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 5.7927
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3077 - val_loss: 6.1587
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3077 - val_loss: 6.6053
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### 코드 분리 (이미지 판정)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# 1. 데이터 로드 및 라벨링
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150

# 6. 새로운 이미지로 예측
def predict_image(image_path, model_path):
    model = load_model(model_path)
    img = load_img(image_path, target_size=(img_width, img_height))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    
    predictions = model.predict(img_array)
    class_indices = train_generator.class_indices
    class_labels = list(class_indices.keys())
    
    for label, probability in zip(class_labels, predictions[0]):
        print(f"{label}: {probability:.4f}")
    
    return predictions[0]

# 예측 테스트
from tkinter import filedialog

test_image_path = filedialog.askopenfile(title = 'Target image')
test_image_path = test_image_path.name
predict_image(test_image_path, model_save_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Cat: 0.9418
# Dog: 0.0006
# Rabbit: 0.0518
# Turtle: 0.0058
# array([9.4179672e-01, 6.0598011e-04, 5.1770814e-02, 5.8264420e-03],
#       dtype=float32)
