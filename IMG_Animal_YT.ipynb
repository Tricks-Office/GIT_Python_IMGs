# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# 1. 데이터 로드 및 라벨링
data_dir = r'C:\Data\Sample\Animals2'  # 각 폴더가 들어있는 상위 폴더 경로
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150
batch_size = 32
epochs = 50

# 2. 데이터 생성기
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# 3. CNN 모델 구성
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# 4. 모델 학습
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs
)

# 5. 모델 저장
model.save(model_save_path)

# 6. 새로운 이미지로 예측
def predict_image(image_path, model_path):
    model = load_model(model_path)
    img = load_img(image_path, target_size=(img_width, img_height))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    
    predictions = model.predict(img_array)
    class_indices = train_generator.class_indices
    class_labels = list(class_indices.keys())
    
    for label, probability in zip(class_labels, predictions[0]):
        print(f"{label}: {probability:.4f}")
    
    return predictions[0]

# 예측 테스트
test_image_path = r'C:\Data\Sample\Beauty.jpg'
predict_image(test_image_path, model_save_path)
# Out:
# Found 38 images belonging to 4 classes.
# Found 13 images belonging to 4 classes.
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1250 - loss: 1.3927 - val_accuracy: 0.3077 - val_loss: 2.6522
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.3333 - loss: 2.9896 - val_accuracy: 0.3077 - val_loss: 2.3999
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 2.3999
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2188 - loss: 2.2647 - val_accuracy: 0.3077 - val_loss: 1.4683
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.5000 - loss: 1.7340 - val_accuracy: 0.2308 - val_loss: 1.3474
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.3474
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7188 - loss: 1.2199 - val_accuracy: 0.1538 - val_loss: 1.3999
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.6667 - loss: 1.1989 - val_accuracy: 0.1538 - val_loss: 1.4325
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.4325
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.6608 - val_accuracy: 0.2308 - val_loss: 2.1670
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.3438 - loss: 1.8739 - val_accuracy: 0.3077 - val_loss: 1.5737
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.5737
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1667 - loss: 1.6700 - val_accuracy: 0.2308 - val_loss: 1.5317
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.5000 - loss: 1.1225 - val_accuracy: 0.2308 - val_loss: 1.6257
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.6257
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 0.8778 - val_accuracy: 0.2308 - val_loss: 1.6571
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.5000 - loss: 1.1514 - val_accuracy: 0.1538 - val_loss: 1.5361
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.5361
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.6390 - val_accuracy: 0.2308 - val_loss: 1.6861
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.4375 - loss: 1.0152 - val_accuracy: 0.2308 - val_loss: 1.4895
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.4895
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 0.6217 - val_accuracy: 0.1538 - val_loss: 1.4184
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7188 - loss: 0.7170 - val_accuracy: 0.1538 - val_loss: 1.4471
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.4471
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8125 - loss: 0.6370 - val_accuracy: 0.3846 - val_loss: 1.5926
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 1.0000 - loss: 0.2279 - val_accuracy: 0.2308 - val_loss: 1.8112
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.8112
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1931 - val_accuracy: 0.1538 - val_loss: 2.1383
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step - accuracy: 0.8125 - loss: 0.4207 - val_accuracy: 0.1538 - val_loss: 2.3711
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.3711
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9062 - loss: 0.3033 - val_accuracy: 0.2308 - val_loss: 2.5959
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8333 - loss: 0.2884 - val_accuracy: 0.1538 - val_loss: 2.6114
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 2.6114
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0904 - val_accuracy: 0.2308 - val_loss: 2.8237
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - accuracy: 0.9062 - loss: 0.2099 - val_accuracy: 0.3846 - val_loss: 2.7861
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 2.7861
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0689 - val_accuracy: 0.1538 - val_loss: 3.2007
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 1.0000 - loss: 0.0824 - val_accuracy: 0.1538 - val_loss: 3.3429
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 3.3429
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0520 - val_accuracy: 0.2308 - val_loss: 3.2177
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.3077 - val_loss: 3.3927
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 3.3927
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.2308 - val_loss: 3.8659
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.2308 - val_loss: 4.3430
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 4.3430
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.2308 - val_loss: 4.8552
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 1.0000 - loss: 0.0356 - val_accuracy: 0.2308 - val_loss: 4.8173
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 4.8173
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.1538 - val_loss: 4.9453
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.2308 - val_loss: 5.5601
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Cat: 0.2252
# Dog: 0.0164
# Rabbit: 0.7229
# Turtle: 0.0355
# array([0.22521363, 0.01642539, 0.7228916 , 0.03546933], dtype=float32)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

from tkinter import filedialog

# 1. 데이터 로드 및 라벨링
data_dir = filedialog.askdirectory()
# data_dir = r'C:\Data\Sample\Animals2'  # 각 폴더가 들어있는 상위 폴더 경로
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150
batch_size = 32
epochs = 50

# 2. 데이터 생성기
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# 3. CNN 모델 구성
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# 4. 모델 학습
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs
)

# 5. 모델 저장
model.save(model_save_path)

# # 6. 새로운 이미지로 예측
# def predict_image(image_path, model_path):
#     model = load_model(model_path)
#     img = load_img(image_path, target_size=(img_width, img_height))
#     img_array = img_to_array(img) / 255.0
#     img_array = np.expand_dims(img_array, axis=0)
    
#     predictions = model.predict(img_array)
#     class_indices = train_generator.class_indices
#     class_labels = list(class_indices.keys())
    
#     for label, probability in zip(class_labels, predictions[0]):
#         print(f"{label}: {probability:.4f}")
    
#     return predictions[0]

# # 예측 테스트
# test_image_path = r'C:\Data\Sample\Beauty.jpg'
# predict_image(test_image_path, model_save_path)
# Out:
# Found 38 images belonging to 4 classes.
# Found 13 images belonging to 4 classes.
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3333 - loss: 1.3494 - val_accuracy: 0.0769 - val_loss: 9.0838
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step - accuracy: 0.0625 - loss: 8.2645 - val_accuracy: 0.2308 - val_loss: 4.7312
# Epoch 3/50
# c:\Users\550sn\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 4.7312
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3333 - loss: 3.4145 - val_accuracy: 0.3077 - val_loss: 2.0251
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - accuracy: 0.3438 - loss: 2.0687 - val_accuracy: 0.2308 - val_loss: 1.2656
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.2656
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5938 - loss: 1.3363 - val_accuracy: 0.3846 - val_loss: 1.3195
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.5000 - loss: 1.2473 - val_accuracy: 0.3846 - val_loss: 1.3261
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.3261
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 1.1394 - val_accuracy: 0.3846 - val_loss: 1.3497
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.3438 - loss: 1.4205 - val_accuracy: 0.3846 - val_loss: 1.2910
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.2910
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4062 - loss: 1.2200 - val_accuracy: 0.1538 - val_loss: 1.2934
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.6667 - loss: 1.2617 - val_accuracy: 0.2308 - val_loss: 1.5134
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.5134
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 1.1836 - val_accuracy: 0.3077 - val_loss: 1.6087
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.2500 - loss: 1.5300 - val_accuracy: 0.3077 - val_loss: 1.4690
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.4690
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3438 - loss: 1.2689 - val_accuracy: 0.3077 - val_loss: 1.3478
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.3333 - loss: 1.2430 - val_accuracy: 0.3846 - val_loss: 1.2941
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.2941
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4062 - loss: 1.1117 - val_accuracy: 0.3846 - val_loss: 1.3523
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.3333 - loss: 1.5266 - val_accuracy: 0.3846 - val_loss: 1.3794
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 1.3794
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 1.1091 - val_accuracy: 0.2308 - val_loss: 1.4508
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.5000 - loss: 1.2177 - val_accuracy: 0.2308 - val_loss: 1.4734
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.4734
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5312 - loss: 1.0128 - val_accuracy: 0.2308 - val_loss: 1.4728
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.5000 - loss: 1.3026 - val_accuracy: 0.1538 - val_loss: 1.3716
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.3716
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.7627 - val_accuracy: 0.2308 - val_loss: 1.3966
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.5938 - loss: 0.9272 - val_accuracy: 0.2308 - val_loss: 1.4167
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.4167
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8333 - loss: 0.8654 - val_accuracy: 0.3077 - val_loss: 1.5033
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7500 - loss: 0.7777 - val_accuracy: 0.3077 - val_loss: 1.6710
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3077 - val_loss: 1.6710
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6875 - loss: 0.6802 - val_accuracy: 0.3846 - val_loss: 1.6367
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8333 - loss: 0.7039 - val_accuracy: 0.1538 - val_loss: 1.6860
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1538 - val_loss: 1.6860
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.3123 - val_accuracy: 0.2308 - val_loss: 2.1667
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - accuracy: 0.6562 - loss: 0.7542 - val_accuracy: 0.2308 - val_loss: 1.9682
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.9682
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8438 - loss: 0.3595 - val_accuracy: 0.3846 - val_loss: 1.9820
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.8333 - loss: 0.4739 - val_accuracy: 0.2308 - val_loss: 1.9989
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.2308 - val_loss: 1.9989
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8438 - loss: 0.3628 - val_accuracy: 0.3077 - val_loss: 2.0340
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 1.0000 - loss: 0.3423 - val_accuracy: 0.3846 - val_loss: 2.0397
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3846 - val_loss: 2.0397
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1337 - val_accuracy: 0.3846 - val_loss: 2.1939
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - accuracy: 0.9375 - loss: 0.2151 - val_accuracy: 0.3077 - val_loss: 2.4567
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

from tkinter import filedialog

# 1. 데이터 로드 및 라벨링
model_save_path = 'cnn_model.h5'
img_width, img_height = 150, 150

# 6. 새로운 이미지로 예측
def predict_image(image_path, model_path):
    model = load_model(model_path)
    img = load_img(image_path, target_size=(img_width, img_height))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    
    predictions = model.predict(img_array)
    class_indices = train_generator.class_indices
    class_labels = list(class_indices.keys())
    
    for label, probability in zip(class_labels, predictions[0]):
        print(f"{label}: {probability:.4f}")
    
    return predictions[0]

# 예측 테스트
test_image_path = filedialog.askopenfilename()
# test_image_path = r'C:\Data\Sample\Beauty.jpg'
predict_image(test_image_path, model_save_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Cat: 0.6221
# Dog: 0.1069
# Rabbit: 0.0810
# Turtle: 0.1900
# array([0.6221457 , 0.10685916, 0.0809714 , 0.1900237 ], dtype=float32)
